# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
white_pixels = [255,255,255]
black_pixels=[0,0,0]
img1 = cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_0_char_148_(24, 17, 3)_BOUYGUES_XML_0_1841822399_0001_2160_2177_112_136.png')
img2=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_0_char_148_(24, 17, 3)_BOUYGUES_XML_0_1841822399_0001_2160_2177_112_136.png')
img3=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_1_char_1204_(37, 24, 3)_BOUYGUES_XML_0_1841822399_0001_1890_1914_2442_2479.png')
img4=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_1_char_1204_(37, 24, 3)_BOUYGUES_XML_0_1841822399_0001_1890_1914_2442_2479.png')
img5=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_2_switched_char_311_(27, 18, 3)_BOUYGUES_XML_0_1841822399_0001_1413_1431_430_457.png')
img6=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_2_switched_char_311_(27, 18, 3)_BOUYGUES_XML_0_1841822399_0001_1413_1431_430_457.png')
img7=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_8_switched_char_1009_(24, 15, 3)_BOUYGUES_XML_0_1841822399_0001_1503_1518_2050_2074.png')
img8=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_8_switched_char_1009_(24, 15, 3)_BOUYGUES_XML_0_1841822399_0001_1503_1518_2050_2074.png')

img9=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_5_switched_char_1206_(36, 31, 3)_BOUYGUES_XML_0_1841822399_0001_1964_1995_2445_2481.png')
img10=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_5_switched_char_1206_(36, 31, 3)_BOUYGUES_XML_0_1841822399_0001_1964_1995_2445_2481.png')
#constant= cv2.copyMakeBorder(img1,75,76,55,56,cv2.BORDER_CONSTANT,value=white_pixels)
#constant2= cv2.copyMakeBorder(img1,75,76,55,56,cv2.BORDER_CONSTANT,value=black_pixels)
#resized=cv2.resize(img1, (32, 32), interpolation=cv2.INTER_NEAREST)

print(img1.shape)
# Out:
# (96, 100, 3)

# %%
'''
white_pixels = [255,255,255]
black_pixels=[0,0,0]
img2 = cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/cropped_images/s_char_123_(18, 15, 3)_BOUYGUES_XML_0_1841822399_0001_1728_1743_120_138.png')
constant3= cv2.copyMakeBorder(img2,51,51,43,43,cv2.BORDER_CONSTANT,value=white_pixels)
constant4= cv2.copyMakeBorder(img2,51,51,43,43,cv2.BORDER_CONSTANT,value=black_pixels)
#resized=cv2.resize(img1, (32, 32), interpolation=cv2.INTER_NEAREST)
print(constant3.shape)
print(img2.shape)
'''

# %%
# %matplotlib inline
plt.subplot(331),plt.imshow(img1,'gray')#,plt.title('Black pixels padding')
plt.subplot(332),plt.imshow(img2,'gray')#,plt.title('White pixels padding')
plt.subplot(333),plt.imshow(img3,'gray')#,plt.title('Black pixels padding')
plt.subplot(334),plt.imshow(img4,'gray')#,plt.title('White pixels padding')
plt.subplot(335),plt.imshow(img5,'gray')#,plt.title('Black pixels padding')
plt.subplot(336),plt.imshow(img6,'gray')#,plt.title('White pixels padding')


plt.subplot(337),plt.imshow(img7,'gray')#,plt.title('Black pixels padding')
plt.subplot(338),plt.imshow(img8,'gray')#,plt.title('White pixels padding')
plt.subplot(339),plt.imshow(img9,'gray')#,plt.title('Black pixels padding')
#plt.subplot(440),plt.imshow(img10,'gray')#,plt.title('Black pixels padding')
#plt.subplot(340),plt.imshow(img4,'gray')#,plt.title('White pixels padding')
#plt.subplot(341),plt.imshow(img5,'gray')#,plt.title('Black pixels padding')
#plt.subplot(342),plt.imshow(img6,'gray')#,plt.title('White pixels padding')
plt.show()

# %%
img1 = cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_,_switched_char_1247_(9, 5, 3)_BOUYGUES_XML_0_1841822399_0001_2280_2285_2019_2028.png')
img2=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_,_switched_char_1247_(9, 5, 3)_BOUYGUES_XML_0_1841822399_0001_2280_2285_2019_2028.png')
img3=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_V_char_1865_(35, 33, 3)_BOUYGUES_XML_0_1841822399_0001_1364_1397_2724_2759.png')
img4=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_V_char_1865_(35, 33, 3)_BOUYGUES_XML_0_1841822399_0001_1364_1397_2724_2759.png')
img5=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_J_char_1866_(45, 36, 3)_BOUYGUES_XML_0_1841822399_0001_1853_1889_2716_2761.png')
img6=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_J_char_1866_(45, 36, 3)_BOUYGUES_XML_0_1841822399_0001_1853_1889_2716_2761.png')
img7=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_black_J_switched_char_1256_(64, 24, 3)_BOUYGUES_XML_0_1841822399_0001_2345_2369_2034_2098.png')
img8=cv2.imread('/home/ahmed/internship/cnn_ocr/scale_train/dataset/_white_J_switched_char_1256_(64, 24, 3)_BOUYGUES_XML_0_1841822399_0001_2345_2369_2034_2098.png')

# %%
# %matplotlib inline
plt.subplot(331),plt.imshow(img1,'gray')#,plt.title('Black pixels padding')
plt.subplot(332),plt.imshow(img2,'gray')#,plt.title('White pixels padding')
plt.subplot(333),plt.imshow(img3,'gray')#,plt.title('Black pixels padding')
plt.subplot(334),plt.imshow(img4,'gray')#,plt.title('White pixels padding')
plt.subplot(335),plt.imshow(img5,'gray')#,plt.title('Black pixels padding')
plt.subplot(336),plt.imshow(img6,'gray')#,plt.title('White pixels padding')


plt.subplot(337),plt.imshow(img7,'gray')#,plt.title('Black pixels padding')
plt.subplot(338),plt.imshow(img8,'gray')#,plt.title('White pixels padding')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7ff52ead4490>,
#  <matplotlib.image.AxesImage at 0x7ff52d3d2cd0>)
